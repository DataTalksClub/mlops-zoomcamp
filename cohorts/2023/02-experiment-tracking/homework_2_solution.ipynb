# %%
# !mlflow --version
# Out:
# mlflow, version 2.2.2

# %%
# !python homework/preprocess_data.py --raw_data_path . --dest_path ./output

# %%
import sys

# %%
# !ls -lh --block-size=k output/dv.pkl
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 151K May 30 11:36 output/dv.pkl

# %%
# !python homework/train.py  --data_path ./output

#Tracking_uri:  http://localhost:5000
#Artifact_uri:  mlflow-artifacts:/53/84473f1f172146b1a3a40e0c2d80c25d/artifacts
#Model saved in run 84473f1f172146b1a3a40e0c2d80c25d

# %% [markdown]
# ![mlops_week_2.jpeg](attachment:mlops_week_2.jpeg)

# %%
# !python homework/hpo.py
# Out:
# [I 2023-05-30 14:27:31,208] A new study created in memory with name: no-name-342c4929-5109-400b-afc6-075dbf90e67d
# [I 2023-05-30 14:27:32,510] Trial 0 finished with value: 2.451379690825458 and parameters: {'n_estimators': 25, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 0 with value: 2.451379690825458.
# [I 2023-05-30 14:27:32,792] Trial 1 finished with value: 2.4667366020368333 and parameters: {'n_estimators': 16, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 0 with value: 2.451379690825458.
# [I 2023-05-30 14:27:33,959] Trial 2 finished with value: 2.449827329704216 and parameters: {'n_estimators': 34, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 2 with value: 2.449827329704216.
# ...

# %%
# !python homework/register_model.py
# Out:
# 2023/05/30 14:41:20 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2023/05/30 14:41:25 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/ubuntu/data/anaconda3/envs/mlflow_env/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# Registered model 'random-forest-hyperopt-best-model' already exists. Creating a new version of this model...
# 2023/05/30 14:41:37 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: random-forest-hyperopt-best-model, version 2
# Created version '2' of model 'random-forest-hyperopt-best-model'.
