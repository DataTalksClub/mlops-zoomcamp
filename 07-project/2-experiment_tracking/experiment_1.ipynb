# %%
import mlflow
import pandas as pd
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("my-fakenews-exp")
# Out:
# 2023/08/03 10:36:07 INFO mlflow.tracking.fluent: Experiment with name 'my-fakenews-exp' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/1', creation_time=1691048167168, experiment_id='1', last_update_time=1691048167168, lifecycle_stage='active', name='my-fakenews-exp', tags={}>

# %%
import pandas as pd
import numpy as np
import io

df = pd.read_csv("../data_embeddings.csv",index_col=0)

# %%
def convert(item):
    item = item.strip()  # remove spaces at the end
    item = item[1:-1]    # remove `[ ]`
    item = np.fromstring(item, sep=' ')  # convert string to `numpy.array`
    return item

# %%
df['vector'] = df['vector'].apply(convert)

# %%
df = shuffle(df)

# %%
X = df['vector']
y = df['label']

# %%
X = np.stack(X)
y = np.stack(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
# array([[-1.68420076,  1.45088935,  0.61488074, ..., -2.21393132,
#         -2.52793598,  3.36729574],
#        [ 1.85769737, -0.08555415, -0.85656333, ..., -0.02918896,
#         -2.04332209,  0.4353711 ],
#        [ 2.41446924,  1.38886416,  1.1026305 , ...,  0.78477639,
#         -4.37773943, -0.21611169],
#        ...,
#        [ 2.6249728 ,  1.3768976 , -0.15828745, ...,  0.68418068,
#         -1.7570008 , -1.0424373 ],
#        [-0.7922892 ,  2.16502476,  0.17109841, ..., -2.42561841,
#         -2.25083399,  0.85438538],
#        [ 1.0791308 ,  3.4378664 , -2.8512676 , ...,  0.86695004,
#         -0.85227174,  0.8357892 ]])

# %%
with mlflow.start_run():
    mlflow.set_tag("data_scientist", "Rollan")

    mlflow.log_param("data_path", "../data_embeddings.csv")

    C = 0.03
    mlflow.log_param("regularization", C)

    lr = LogisticRegression(C=C)
    lr.fit(X_train, y_train)
 
    y_pred = lr.predict(X_test)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mlflow.log_metric("accuracy", rmse)
# Out:
# /opt/anaconda3/envs/mlflow-env/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials  #helps to optimize hyperparameters
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_test, label=y_test)

# %%
def obj(params):

    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=30,
            evals=[(valid, "test")],
            early_stopping_rounds=20
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
    
    return {"loss":rmse, "status":STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 30, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=obj,
    space=search_space,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()
)
# Out:
# [17:00:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.47174
# [1]	test-rmse:0.44533
# [2]	test-rmse:0.42049
# [3]	test-rmse:0.39704
# [4]	test-rmse:0.37532
# [5]	test-rmse:0.35481
# [6]	test-rmse:0.33586
# [7]	test-rmse:0.31798
# [8]	test-rmse:0.30134
# [9]	test-rmse:0.28566
# [10]	test-rmse:0.27111
# [11]	test-rmse:0.25742
# [12]	test-rmse:0.24464
# [13]	test-rmse:0.23285
# [14]	test-rmse:0.22174
# [15]	test-rmse:0.21140
# [16]	test-rmse:0.20189
# [17]	test-rmse:0.19291
# [18]	test-rmse:0.18465
# [19]	test-rmse:0.17687
# [20]	test-rmse:0.16971
# [21]	test-rmse:0.16323
# [22]	test-rmse:0.15708
# [23]	test-rmse:0.15147
# [24]	test-rmse:0.14622
# [25]	test-rmse:0.14139
# [26]	test-rmse:0.13687
# [27]	test-rmse:0.13278
# [28]	test-rmse:0.12909
# [29]	test-rmse:0.12566
# [17:00:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.42752
# [1]	test-rmse:0.36668
# [2]	test-rmse:0.31568
# [3]	test-rmse:0.27362
# [4]	test-rmse:0.23832
# [5]	test-rmse:0.20909
# [6]	test-rmse:0.18498
# [7]	test-rmse:0.16559
# [8]	test-rmse:0.14971
# [9]	test-rmse:0.13699
# [10]	test-rmse:0.12661
# [11]	test-rmse:0.11860
# [12]	test-rmse:0.11202
# [13]	test-rmse:0.10668
# [14]	test-rmse:0.10260
# [15]	test-rmse:0.09943
# [16]	test-rmse:0.09686
# [17]	test-rmse:0.09474
# [18]	test-rmse:0.09295
# [19]	test-rmse:0.09147
# [20]	test-rmse:0.09048
# [21]	test-rmse:0.08949
# [22]	test-rmse:0.08863
# [23]	test-rmse:0.08803
# [24]	test-rmse:0.08744
# [25]	test-rmse:0.08696
# [26]	test-rmse:0.08655
# [27]	test-rmse:0.08620
# [28]	test-rmse:0.08587
# [29]	test-rmse:0.08559
# [17:01:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.25250
# [1]	test-rmse:0.15293
# [2]	test-rmse:0.11892
# [3]	test-rmse:0.10881
# [4]	test-rmse:0.10604
# [5]	test-rmse:0.10438
# [6]	test-rmse:0.10370
# [7]	test-rmse:0.10343
# [8]	test-rmse:0.10308
# [9]	test-rmse:0.10294
# [10]	test-rmse:0.10275
# [11]	test-rmse:0.10267
# [12]	test-rmse:0.10261
# [13]	test-rmse:0.10250
# [14]	test-rmse:0.10245
# [15]	test-rmse:0.10237
# [16]	test-rmse:0.10236
# [17]	test-rmse:0.10234
# [18]	test-rmse:0.10233
# [19]	test-rmse:0.10232
# [20]	test-rmse:0.10231
# [21]	test-rmse:0.10229
# [22]	test-rmse:0.10229
# [23]	test-rmse:0.10225
# [24]	test-rmse:0.10224
# [25]	test-rmse:0.10226
# [26]	test-rmse:0.10224
# [27]	test-rmse:0.10226
# [28]	test-rmse:0.10225
# [29]	test-rmse:0.10224
# [17:02:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.16504
# [1]	test-rmse:0.12660
# [2]	test-rmse:0.12316
# [3]	test-rmse:0.12314
# [4]	test-rmse:0.12285
# [5]	test-rmse:0.12289
# [6]	test-rmse:0.12301
# [7]	test-rmse:0.12305
# [8]	test-rmse:0.12292
# [9]	test-rmse:0.12298
# [10]	test-rmse:0.12307
# [11]	test-rmse:0.12288
# [12]	test-rmse:0.12291
# [13]	test-rmse:0.12293
# [14]	test-rmse:0.12289
# [15]	test-rmse:0.12281
# [16]	test-rmse:0.12278
# [17]	test-rmse:0.12281
# [18]	test-rmse:0.12276
# [19]	test-rmse:0.12275
# [20]	test-rmse:0.12276
# [21]	test-rmse:0.12277
# [22]	test-rmse:0.12278
# [23]	test-rmse:0.12278
# [24]	test-rmse:0.12278
# [25]	test-rmse:0.12277
# [26]	test-rmse:0.12277
# [27]	test-rmse:0.12278
# [28]	test-rmse:0.12278
# [29]	test-rmse:0.12278
# [17:03:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.26495
# [1]	test-rmse:0.16442
# [2]	test-rmse:0.12868
# [3]	test-rmse:0.11795
# [4]	test-rmse:0.11256
# [5]	test-rmse:0.11030
# [6]	test-rmse:0.10858
# [7]	test-rmse:0.10750
# [8]	test-rmse:0.10680
# [9]	test-rmse:0.10631
# [10]	test-rmse:0.10586
# [11]	test-rmse:0.10558
# [12]	test-rmse:0.10519
# [13]	test-rmse:0.10495
# [14]	test-rmse:0.10443
# [15]	test-rmse:0.10450
# [16]	test-rmse:0.10419
# [17]	test-rmse:0.10411
# [18]	test-rmse:0.10383
# [19]	test-rmse:0.10368
# [20]	test-rmse:0.10354
# [21]	test-rmse:0.10343
# [22]	test-rmse:0.10333
# [23]	test-rmse:0.10339
# [24]	test-rmse:0.10332
# [25]	test-rmse:0.10334
# [26]	test-rmse:0.10323
# [27]	test-rmse:0.10314
# [28]	test-rmse:0.10316
# [29]	test-rmse:0.10304
# [17:03:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.38530
# [1]	test-rmse:0.29970
# [2]	test-rmse:0.23761
# [3]	test-rmse:0.19226
# [4]	test-rmse:0.15985
# [5]	test-rmse:0.13770
# [6]	test-rmse:0.12290
# [7]	test-rmse:0.11257
# [8]	test-rmse:0.10597
# [9]	test-rmse:0.10154
# [10]	test-rmse:0.09865
# [11]	test-rmse:0.09649
# [12]	test-rmse:0.09483
# [13]	test-rmse:0.09377
# [14]	test-rmse:0.09306
# [15]	test-rmse:0.09248
# [16]	test-rmse:0.09219
# [17]	test-rmse:0.09175
# [18]	test-rmse:0.09143
# [19]	test-rmse:0.09120
# [20]	test-rmse:0.09100
# [21]	test-rmse:0.09087
# [22]	test-rmse:0.09067
# [23]	test-rmse:0.09048
# [24]	test-rmse:0.09036
# [25]	test-rmse:0.09029
# [26]	test-rmse:0.09021
# [27]	test-rmse:0.09016
# [28]	test-rmse:0.09012
# [29]	test-rmse:0.09007
# [17:03:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.46372
# [1]	test-rmse:0.43035
# [2]	test-rmse:0.39965
# [3]	test-rmse:0.37143
# [4]	test-rmse:0.34570
# [5]	test-rmse:0.32161
# [6]	test-rmse:0.29953
# [7]	test-rmse:0.27968
# [8]	test-rmse:0.26125
# [9]	test-rmse:0.24435
# [10]	test-rmse:0.22888
# [11]	test-rmse:0.21477
# [12]	test-rmse:0.20196
# [13]	test-rmse:0.19040
# [14]	test-rmse:0.17977
# [15]	test-rmse:0.17008
# [16]	test-rmse:0.16131
# [17]	test-rmse:0.15338
# [18]	test-rmse:0.14624
# [19]	test-rmse:0.13986
# [20]	test-rmse:0.13400
# [21]	test-rmse:0.12885
# [22]	test-rmse:0.12417
# [23]	test-rmse:0.12003
# [24]	test-rmse:0.11635
# [25]	test-rmse:0.11315
# [26]	test-rmse:0.11027
# [27]	test-rmse:0.10778
# [28]	test-rmse:0.10557
# [29]	test-rmse:0.10359
# [17:04:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.17629
# [1]	test-rmse:0.13063
# [2]	test-rmse:0.12596
# [3]	test-rmse:0.12507
# [4]	test-rmse:0.12488
# [5]	test-rmse:0.12481
# [6]	test-rmse:0.12472
# [7]	test-rmse:0.12470
# [8]	test-rmse:0.12468
# [9]	test-rmse:0.12466
# [10]	test-rmse:0.12464
# [11]	test-rmse:0.12463
# [12]	test-rmse:0.12462
# [13]	test-rmse:0.12462
# [14]	test-rmse:0.12461
# [15]	test-rmse:0.12461
# [16]	test-rmse:0.12461
# [17]	test-rmse:0.12460
# [18]	test-rmse:0.12460
# [19]	test-rmse:0.12460
# [20]	test-rmse:0.12460
# [21]	test-rmse:0.12460
# [22]	test-rmse:0.12459
# [23]	test-rmse:0.12459
# [24]	test-rmse:0.12459
# [25]	test-rmse:0.12459
# [26]	test-rmse:0.12459
# [27]	test-rmse:0.12459
# [28]	test-rmse:0.12459
# [29]	test-rmse:0.12459
# [17:04:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.31914
# [1]	test-rmse:0.21384
# [2]	test-rmse:0.15468
# [3]	test-rmse:0.12416
# [4]	test-rmse:0.10906
# [5]	test-rmse:0.10171
# [6]	test-rmse:0.09815
# [7]	test-rmse:0.09624
# [8]	test-rmse:0.09506
# [9]	test-rmse:0.09434
# [10]	test-rmse:0.09404
# [11]	test-rmse:0.09376
# [12]	test-rmse:0.09343
# [13]	test-rmse:0.09325
# [14]	test-rmse:0.09310
# [15]	test-rmse:0.09297
# [16]	test-rmse:0.09284
# [17]	test-rmse:0.09278
# [18]	test-rmse:0.09275
# [19]	test-rmse:0.09272
# [20]	test-rmse:0.09268
# [21]	test-rmse:0.09264
# [22]	test-rmse:0.09262
# [23]	test-rmse:0.09261
# [24]	test-rmse:0.09260
# [25]	test-rmse:0.09259
# [26]	test-rmse:0.09258
# [27]	test-rmse:0.09253
# [28]	test-rmse:0.09254
# [29]	test-rmse:0.09253
# [17:05:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.39435
# [1]	test-rmse:0.31361
# [2]	test-rmse:0.25239
# [3]	test-rmse:0.20636
# [4]	test-rmse:0.17270
# [5]	test-rmse:0.14746
# [6]	test-rmse:0.13012
# [7]	test-rmse:0.11806
# [8]	test-rmse:0.10927
# [9]	test-rmse:0.10327
# [10]	test-rmse:0.09892
# [11]	test-rmse:0.09577
# [12]	test-rmse:0.09349
# [13]	test-rmse:0.09192
# [14]	test-rmse:0.09080
# [15]	test-rmse:0.08991
# [16]	test-rmse:0.08924
# [17]	test-rmse:0.08869
# [18]	test-rmse:0.08822
# [19]	test-rmse:0.08786
# [20]	test-rmse:0.08750
# [21]	test-rmse:0.08718
# [22]	test-rmse:0.08692
# [23]	test-rmse:0.08675
# [24]	test-rmse:0.08659
# [25]	test-rmse:0.08643
# [26]	test-rmse:0.08628
# [27]	test-rmse:0.08617
# [28]	test-rmse:0.08604
# [29]	test-rmse:0.08597
# 100%|██████████| 10/10 [05:47<00:00, 34.72s/trial, best loss: 0.0855919766756668]

# %%
params = {
    'learning_rate': 0.13998783607276,
    'max_depth': 28,
    'min_child_weight':	0.8037214370553903,
    'objective': 'reg:linear',
    'reg_alpha': 0.007917567259199893,
    'reg_lambda': 0.00982476912100121,
    'seed': 42
}


mlflow.xgboost.autolog()
booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=30,
            evals=[(valid, "test")],
            early_stopping_rounds=20
        )
# Out:
# 2023/08/03 17:28:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd93c183ac28f4fac8d27ef526b0955fc', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [17:28:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:0.43365
# [1]	test-rmse:0.37732
# [2]	test-rmse:0.32988
# [3]	test-rmse:0.29038
# [4]	test-rmse:0.25754
# [5]	test-rmse:0.23008
# [6]	test-rmse:0.20772
# [7]	test-rmse:0.18989
# [8]	test-rmse:0.17535
# [9]	test-rmse:0.16406
# [10]	test-rmse:0.15544
# [11]	test-rmse:0.14883
# [12]	test-rmse:0.14395
# [13]	test-rmse:0.14030
# [14]	test-rmse:0.13739
# [15]	test-rmse:0.13541
# [16]	test-rmse:0.13378
# [17]	test-rmse:0.13280
# [18]	test-rmse:0.13198
# [19]	test-rmse:0.13137
# [20]	test-rmse:0.13087
# [21]	test-rmse:0.13045
# [22]	test-rmse:0.13012
# [23]	test-rmse:0.12989
# [24]	test-rmse:0.12970
# [25]	test-rmse:0.12955
# [26]	test-rmse:0.12943
# [27]	test-rmse:0.12935
# [28]	test-rmse:0.12927
# [29]	test-rmse:0.12920
# 2023/08/03 17:29:04 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2023/08/03 17:29:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/anaconda3/envs/mlflow-env/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
